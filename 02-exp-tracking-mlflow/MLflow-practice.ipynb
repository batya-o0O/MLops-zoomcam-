# %%
# !python -V

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import click

# %%
import os
import pickle
import click
import pandas as pd

from sklearn.feature_extraction import DictVectorizer

def dump_pickle(obj, filename: str):
    with open(filename, "wb") as f_out:
        return pickle.dump(obj, f_out)


def read_dataframe(filename: str):
    df = pd.read_parquet(filename)

    df['duration'] = df['lpep_dropoff_datetime'] - df['lpep_pickup_datetime']
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)
    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)

    return df


def preprocess(df: pd.DataFrame, dv: DictVectorizer, fit_dv: bool = False):
    df['PU_DO'] = df['PULocationID'] + '_' + df['DOLocationID']
    categorical = ['PU_DO']
    numerical = ['trip_distance']
    dicts = df[categorical + numerical].to_dict(orient='records')
    if fit_dv:
        X = dv.fit_transform(dicts)
    else:
        X = dv.transform(dicts)
    return X, dv

def run_data_prep(raw_data_path: str, dest_path: str, dataset: str = "green"):
    # Load parquet files
    df_train = read_dataframe(
        os.path.join(raw_data_path, f"{dataset}_tripdata_2023-01.parquet")
    )
    df_val = read_dataframe(
        os.path.join(raw_data_path, f"{dataset}_tripdata_2023-02.parquet")
    )
    df_test = read_dataframe(
        os.path.join(raw_data_path, f"{dataset}_tripdata_2023-03.parquet")
    )

    # Extract the target
    target = 'duration'
    y_train = df_train[target].values
    y_val = df_val[target].values
    y_test = df_test[target].values

    # Fit the DictVectorizer and preprocess data
    dv = DictVectorizer()
    X_train, dv = preprocess(df_train, dv, fit_dv=True)
    X_val, _ = preprocess(df_val, dv, fit_dv=False)
    X_test, _ = preprocess(df_test, dv, fit_dv=False)

    # Create dest_path folder unless it already exists
    os.makedirs(dest_path, exist_ok=True)

    # Save DictVectorizer and datasets
    dump_pickle(dv, os.path.join(dest_path, "dv.pkl"))
    dump_pickle((X_train, y_train), os.path.join(dest_path, "train.pkl"))
    dump_pickle((X_val, y_val), os.path.join(dest_path, "val.pkl"))
    dump_pickle((X_test, y_test), os.path.join(dest_path, "test.pkl"))

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso

from sklearn.metrics import mean_squared_error

# %%
import mlflow

mlflow.set_tracking_uri("postgresql+psycopg2://postgres:Batya@localhost:5433/mlflow")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/home/batya/notebooks/MLops-zoomcamp/02-exp-tracking-mlflow/mlruns/1', creation_time=1716636737730, experiment_id='1', last_update_time=1716636737730, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
df = pd.read_parquet('./data/green_tripdata_2023-01.parquet')

df['duration'] = df['lpep_dropoff_datetime'] - df['lpep_pickup_datetime']
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

df = df[(df['duration'] >=1) & (df['duration'] <= 60)]

categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

df[categorical] = df[categorical].astype(str)

# %%
train_dicts = df[categorical + numerical].to_dict(orient='records')

dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

target = 'duration'
y_train = df[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_train)

mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 7.0603515317164085

# %%
def read_dataframe(filename):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)

        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    elif filename.endswith('.parquet'):
        df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2023-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2023-02.parquet')

# %%
categorical = ['PULocationID', 'DOLocationID']
train_dicts = df_train[categorical].to_dict(orient='records')
val_dicts = df_val[categorical].to_dict(orient='records')

dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)
X_val = dv.transform(val_dicts)

target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.356162221489667

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
categorical = ['PULocationID', 'DOLocationID']
train = xgb.DMatrix(X_train, label = y_train)
val = xgb.DMatrix(X_val, label = y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag('model', 'xgboost')
        mlflow.log_params(params)
        booster = xgb.train(
            params = params,
            dtrain = train,
            num_boost_round = 100,
            evals = [(val, "validation")],
            early_stopping_rounds = 40,
        )
        y_pred = booster.predict(val)
        rmse = mean_squared_error(y_val, y_pred, squared = False)
        mlflow.log_metric('rmse', rmse)

    return {'loss':rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.uniform('max_depth', 4, 100)),
    'learning_rate': hp.loguniform('learning_rate', -4, -1),
    'reg_alpha': hp.loguniform("reg_alpha", -5, -1),
    'reg_lambda': hp.loguniform("reg_lambda", -6, -1),
    'min_child_weight': hp.loguniform("min_child_weight", -1, 3),
    'objective': 'reg:linear',
    'seed': 42,
}

best_result =fmin(
    fn=objective,
    space = search_space,
    algo = tpe.suggest,
    max_evals = 5,
    trials = Trials()
    )
# Out:
#   0%|                                                                                                         | 0/5 [00:00<?, ?trial/s, best loss=?]
# /home/batya/.local/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [20:34:59] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:9.23764
# [1]	validation-rmse:9.15926
# [2]	validation-rmse:9.08749
# [3]	validation-rmse:9.01929
# [4]	validation-rmse:8.95674
# [5]	validation-rmse:8.89795
# [6]	validation-rmse:8.84365
# [7]	validation-rmse:8.79302
# [8]	validation-rmse:8.74629
# [9]	validation-rmse:8.70085
# [10]	validation-rmse:8.66019
# [11]	validation-rmse:8.61933
# [12]	validation-rmse:8.58405
# [13]	validation-rmse:8.54866
# [14]	validation-rmse:8.51744
# [15]	validation-rmse:8.48133
# [16]	validation-rmse:8.45342
# [17]	validation-rmse:8.42096
# [18]	validation-rmse:8.39574
# [19]	validation-rmse:8.37210
# [20]	validation-rmse:8.34424
# [21]	validation-rmse:8.32254
# [22]	validation-rmse:8.30154
# [23]	validation-rmse:8.28175
# [24]	validation-rmse:8.26266
# [25]	validation-rmse:8.24068
# [26]	validation-rmse:8.22181
# [27]	validation-rmse:8.20496
# [28]	validation-rmse:8.18276
# [29]	validation-rmse:8.16690
# [30]	validation-rmse:8.15202
# [31]	validation-rmse:8.13041
# [32]	validation-rmse:8.11568
# [33]	validation-rmse:8.10231
# [34]	validation-rmse:8.08887
# [35]	validation-rmse:8.07288
# [36]	validation-rmse:8.06054
# [37]	validation-rmse:8.04832
# [38]	validation-rmse:8.03618
# [39]	validation-rmse:8.01740
# [40]	validation-rmse:8.00549
# [41]	validation-rmse:7.99486
# [42]	validation-rmse:7.98350
# [43]	validation-rmse:7.97301
# [44]	validation-rmse:7.96291
# [45]	validation-rmse:7.94754
# [46]	validation-rmse:7.93805
# [47]	validation-rmse:7.92759
# [48]	validation-rmse:7.91834
# [49]	validation-rmse:7.90257
# [50]	validation-rmse:7.88656
# [51]	validation-rmse:7.87709
# [52]	validation-rmse:7.86229
# [53]	validation-rmse:7.85426
# [54]	validation-rmse:7.84378
# [55]	validation-rmse:7.83550
# [56]	validation-rmse:7.82637
# [57]	validation-rmse:7.81047
# [58]	validation-rmse:7.79742
# [59]	validation-rmse:7.79002
# [60]	validation-rmse:7.78133
# [61]	validation-rmse:7.77296
# [62]	validation-rmse:7.76513
# [63]	validation-rmse:7.74875
# [64]	validation-rmse:7.74112
# [65]	validation-rmse:7.72876
# [66]	validation-rmse:7.72085
# [67]	validation-rmse:7.71284
# [68]	validation-rmse:7.69813
# [69]	validation-rmse:7.69174
# [70]	validation-rmse:7.68035
# [71]	validation-rmse:7.67306
# [72]	validation-rmse:7.66586
# [73]	validation-rmse:7.65806
# [74]	validation-rmse:7.65115
# [75]	validation-rmse:7.63860
# [76]	validation-rmse:7.62780
# [77]	validation-rmse:7.62168
# [78]	validation-rmse:7.61578
# [79]	validation-rmse:7.60976
# [80]	validation-rmse:7.60029
# [81]	validation-rmse:7.58823
# [82]	validation-rmse:7.57855
# [83]	validation-rmse:7.57196
# [84]	validation-rmse:7.56602
# [85]	validation-rmse:7.55730
# [86]	validation-rmse:7.55221
# [87]	validation-rmse:7.54667
# [88]	validation-rmse:7.54054
# [89]	validation-rmse:7.53435
# [90]	validation-rmse:7.52901
# [91]	validation-rmse:7.52413
# [92]	validation-rmse:7.51399
# [93]	validation-rmse:7.50567
# [94]	validation-rmse:7.50126
# [95]	validation-rmse:7.49567
# [96]	validation-rmse:7.48647
# [97]	validation-rmse:7.47831
# [98]	validation-rmse:7.47283
# [99]	validation-rmse:7.46795
#  20%|████████████████                                                                | 1/5 [00:34<02:17, 34.44s/trial, best loss: 7.467951183353046]
# /home/batya/.local/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [20:35:34] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:8.37216
# [1]	validation-rmse:7.82206
# [2]	validation-rmse:7.49803
# [3]	validation-rmse:7.16746
# [4]	validation-rmse:7.02504
# [5]	validation-rmse:6.86779
# [6]	validation-rmse:6.78071
# [7]	validation-rmse:6.71235
# [8]	validation-rmse:6.65008
# [9]	validation-rmse:6.60701
# [10]	validation-rmse:6.56724
# [11]	validation-rmse:6.47758
# [12]	validation-rmse:6.44273
# [13]	validation-rmse:6.41043
# [14]	validation-rmse:6.38971
# [15]	validation-rmse:6.35482
# [16]	validation-rmse:6.32405
# [17]	validation-rmse:6.30296
# [18]	validation-rmse:6.25873
# [19]	validation-rmse:6.24032
# [20]	validation-rmse:6.23394
# [21]	validation-rmse:6.19835
# [22]	validation-rmse:6.19364
# [23]	validation-rmse:6.15942
# [24]	validation-rmse:6.14237
# [25]	validation-rmse:6.13667
# [26]	validation-rmse:6.12616
# [27]	validation-rmse:6.12138
# [28]	validation-rmse:6.09761
# [29]	validation-rmse:6.06749
# [30]	validation-rmse:6.06427
# [31]	validation-rmse:6.05548
# [32]	validation-rmse:6.05215
# [33]	validation-rmse:6.04711
# [34]	validation-rmse:6.04404
# [35]	validation-rmse:6.04083
# [36]	validation-rmse:6.03607
# [37]	validation-rmse:6.03709
# [38]	validation-rmse:6.03045
# [39]	validation-rmse:6.02544
# [40]	validation-rmse:6.02207
# [41]	validation-rmse:6.01780
# [42]	validation-rmse:6.00061
# [43]	validation-rmse:5.99560
# [44]	validation-rmse:5.99551
# [45]	validation-rmse:5.99356
# [46]	validation-rmse:5.99013
# [47]	validation-rmse:5.99104
# [48]	validation-rmse:5.98858
# [49]	validation-rmse:5.98083
# [50]	validation-rmse:5.98060
# [51]	validation-rmse:5.97941
# [52]	validation-rmse:5.97347
# [53]	validation-rmse:5.97314
# [54]	validation-rmse:5.97298
# [55]	validation-rmse:5.97330
# [56]	validation-rmse:5.97307
# [57]	validation-rmse:5.97378
# [58]	validation-rmse:5.97373
# [59]	validation-rmse:5.97197
# [60]	validation-rmse:5.96926
# [61]	validation-rmse:5.96730
# [62]	validation-rmse:5.96563
# [63]	validation-rmse:5.96730
# [64]	validation-rmse:5.96688
# [65]	validation-rmse:5.96867
# [66]	validation-rmse:5.96845
# [67]	validation-rmse:5.96853
# [68]	validation-rmse:5.96731
# [69]	validation-rmse:5.96547
# [70]	validation-rmse:5.96623
# [71]	validation-rmse:5.96556
# [72]	validation-rmse:5.96477
# [73]	validation-rmse:5.96545
# [74]	validation-rmse:5.96456
# [75]	validation-rmse:5.96517
# [76]	validation-rmse:5.96511
# [77]	validation-rmse:5.96584
# [78]	validation-rmse:5.96528
# [79]	validation-rmse:5.96474
# [80]	validation-rmse:5.96597
# [81]	validation-rmse:5.96555
# [82]	validation-rmse:5.96545
# [83]	validation-rmse:5.96545
# [84]	validation-rmse:5.96517
# [85]	validation-rmse:5.96600
# [86]	validation-rmse:5.96582
# [87]	validation-rmse:5.96566
# [88]	validation-rmse:5.96562
# [89]	validation-rmse:5.96464
# [90]	validation-rmse:5.96494
# [91]	validation-rmse:5.96445
# [92]	validation-rmse:5.96520
# [93]	validation-rmse:5.96413
# [94]	validation-rmse:5.96296
# [95]	validation-rmse:5.96296
# [96]	validation-rmse:5.96088
# [97]	validation-rmse:5.95995
# [98]	validation-rmse:5.95922
# [99]	validation-rmse:5.95923
#  40%|███████████████████████████████▌                                               | 2/5 [02:15<03:41, 73.84s/trial, best loss: 5.9592349738760255]
# /home/batya/.local/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [20:37:15] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:8.14697
# [1]	validation-rmse:7.47231
# [2]	validation-rmse:7.00737
# [3]	validation-rmse:6.77985
# [4]	validation-rmse:6.60290
# [5]	validation-rmse:6.51226
# [6]	validation-rmse:6.45000
# [7]	validation-rmse:6.38508
# [8]	validation-rmse:6.35620
# [9]	validation-rmse:6.32499
# [10]	validation-rmse:6.30858
# [11]	validation-rmse:6.26009
# [12]	validation-rmse:6.23651
# [13]	validation-rmse:6.22090
# [14]	validation-rmse:6.20918
# [15]	validation-rmse:6.19909
# [16]	validation-rmse:6.19294
# [17]	validation-rmse:6.18674
# [18]	validation-rmse:6.17717
# [19]	validation-rmse:6.16116
# [20]	validation-rmse:6.15604
# [21]	validation-rmse:6.15395
# [22]	validation-rmse:6.14787
# [23]	validation-rmse:6.14098
# [24]	validation-rmse:6.13390
# [25]	validation-rmse:6.13103
# [26]	validation-rmse:6.12555
# [27]	validation-rmse:6.11760
# [28]	validation-rmse:6.11019
# [29]	validation-rmse:6.10674
# [30]	validation-rmse:6.10075
# [31]	validation-rmse:6.09536
# [32]	validation-rmse:6.09170
# [33]	validation-rmse:6.09050
# [34]	validation-rmse:6.08635
# [35]	validation-rmse:6.07815
# [36]	validation-rmse:6.07552
# [37]	validation-rmse:6.07249
# [38]	validation-rmse:6.06959
# [39]	validation-rmse:6.06943
# [40]	validation-rmse:6.06696
# [41]	validation-rmse:6.06512
# [42]	validation-rmse:6.06414
# [43]	validation-rmse:6.06357
# [44]	validation-rmse:6.06312
# [45]	validation-rmse:6.06155
# [46]	validation-rmse:6.05974
# [47]	validation-rmse:6.05655
# [48]	validation-rmse:6.05523
# [49]	validation-rmse:6.05401
# [50]	validation-rmse:6.05142
# [51]	validation-rmse:6.05107
# [52]	validation-rmse:6.04935
# [53]	validation-rmse:6.04755
# [54]	validation-rmse:6.04637
# [55]	validation-rmse:6.04620
# [56]	validation-rmse:6.04377
# [57]	validation-rmse:6.04124
# [58]	validation-rmse:6.04280
# [59]	validation-rmse:6.03960
# [60]	validation-rmse:6.03941
# [61]	validation-rmse:6.03878
# [62]	validation-rmse:6.03769
# [63]	validation-rmse:6.03633
# [64]	validation-rmse:6.03434
# [65]	validation-rmse:6.03403
# [66]	validation-rmse:6.03414
# [67]	validation-rmse:6.03049
# [68]	validation-rmse:6.02807
# [69]	validation-rmse:6.02760
# [70]	validation-rmse:6.02702
# [71]	validation-rmse:6.02568
# [72]	validation-rmse:6.02474
# [73]	validation-rmse:6.02435
# [74]	validation-rmse:6.02338
# [75]	validation-rmse:6.02180
# [76]	validation-rmse:6.02153
# [77]	validation-rmse:6.01854
# [78]	validation-rmse:6.01639
# [79]	validation-rmse:6.01489
# [80]	validation-rmse:6.01460
# [81]	validation-rmse:6.01154
# [82]	validation-rmse:6.01118
# [83]	validation-rmse:6.00800
# [84]	validation-rmse:6.00688
# [85]	validation-rmse:6.00475
# [86]	validation-rmse:6.00312
# [87]	validation-rmse:6.00121
# [88]	validation-rmse:5.99896
# [89]	validation-rmse:5.99671
# [90]	validation-rmse:5.99637
# [91]	validation-rmse:5.99434
# [92]	validation-rmse:5.99184
# [93]	validation-rmse:5.98875
# [94]	validation-rmse:5.98623
# [95]	validation-rmse:5.98605
# [96]	validation-rmse:5.98304
# [97]	validation-rmse:5.98347
# [98]	validation-rmse:5.98178
# [99]	validation-rmse:5.97965
#  60%|██████████████████████████████████████████████▊                               | 3/5 [04:55<03:46, 113.21s/trial, best loss: 5.9592349738760255]
# /home/batya/.local/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [20:39:55] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:9.00172
# [1]	validation-rmse:8.71692
# [2]	validation-rmse:8.46534
# [3]	validation-rmse:8.24607
# [4]	validation-rmse:8.04300
# [5]	validation-rmse:7.86466
# [6]	validation-rmse:7.70402
# [7]	validation-rmse:7.55587
# [8]	validation-rmse:7.43633
# [9]	validation-rmse:7.31636
# [10]	validation-rmse:7.22774
# ...
# [97]	validation-rmse:6.25683
# [98]	validation-rmse:6.25486
# [99]	validation-rmse:6.25381
#  80%|██████████████████████████████████████████████████████████████▍               | 4/5 [07:47<02:16, 136.11s/trial, best loss: 5.9592349738760255]
# /home/batya/.local/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [20:42:46] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:8.68352
# [1]	validation-rmse:8.18902
# [2]	validation-rmse:7.79140
# [3]	validation-rmse:7.46293
# [4]	validation-rmse:7.21700
# [5]	validation-rmse:7.02987
# [6]	validation-rmse:6.88707
# [7]	validation-rmse:6.76173
# [8]	validation-rmse:6.66816
# [9]	validation-rmse:6.60169
# [10]	validation-rmse:6.53745
# [11]	validation-rmse:6.47366
# [12]	validation-rmse:6.44051
# [13]	validation-rmse:6.39847
# [14]	validation-rmse:6.37481
# [15]	validation-rmse:6.35489
# [16]	validation-rmse:6.33986
# [17]	validation-rmse:6.32204
# [18]	validation-rmse:6.30751
# [19]	validation-rmse:6.29738
# [20]	validation-rmse:6.28936
# [21]	validation-rmse:6.28106
# [22]	validation-rmse:6.27327
# [23]	validation-rmse:6.26608
# [24]	validation-rmse:6.26020
# [25]	validation-rmse:6.25424
# [26]	validation-rmse:6.24887
# [27]	validation-rmse:6.24524
# [28]	validation-rmse:6.23902
# [29]	validation-rmse:6.23702
# [30]	validation-rmse:6.23391
# [31]	validation-rmse:6.22869
# [32]	validation-rmse:6.22186
# [33]	validation-rmse:6.21724
# [34]	validation-rmse:6.21388
# [35]	validation-rmse:6.21064
# [36]	validation-rmse:6.20571
# [37]	validation-rmse:6.20239
# [38]	validation-rmse:6.20062
# [39]	validation-rmse:6.19796
# [40]	validation-rmse:6.19459
# [41]	validation-rmse:6.18716
# [42]	validation-rmse:6.18598
# [43]	validation-rmse:6.18390
# [44]	validation-rmse:6.18074
# [45]	validation-rmse:6.17833
# [46]	validation-rmse:6.17328
# [47]	validation-rmse:6.16862
# [48]	validation-rmse:6.16586
# [49]	validation-rmse:6.16214
# [50]	validation-rmse:6.15978
# [51]	validation-rmse:6.15785
# [52]	validation-rmse:6.15381
# [53]	validation-rmse:6.15089
# [54]	validation-rmse:6.14786
# [55]	validation-rmse:6.14403
# [56]	validation-rmse:6.14156
# [57]	validation-rmse:6.14067
# [58]	validation-rmse:6.13905
# [59]	validation-rmse:6.13598
# [60]	validation-rmse:6.13498
# [61]	validation-rmse:6.13163
# [62]	validation-rmse:6.12938
# [63]	validation-rmse:6.12714
# [64]	validation-rmse:6.12401
# [65]	validation-rmse:6.12097
# [66]	validation-rmse:6.12022
# [67]	validation-rmse:6.11834
# [68]	validation-rmse:6.11623
# [69]	validation-rmse:6.11597
# [70]	validation-rmse:6.11254
# [71]	validation-rmse:6.11162
# [72]	validation-rmse:6.10936
# [73]	validation-rmse:6.10731
# [74]	validation-rmse:6.10683
# [75]	validation-rmse:6.10494
# [76]	validation-rmse:6.10376
# [77]	validation-rmse:6.10136
# [78]	validation-rmse:6.10040
# [79]	validation-rmse:6.09884
# [80]	validation-rmse:6.09777
# [81]	validation-rmse:6.09643
# [82]	validation-rmse:6.09447
# [83]	validation-rmse:6.09320
# [84]	validation-rmse:6.09210
# [85]	validation-rmse:6.09002
# [86]	validation-rmse:6.08901
# [87]	validation-rmse:6.08763
# [88]	validation-rmse:6.08625
# [89]	validation-rmse:6.08548
# [90]	validation-rmse:6.08358
# [91]	validation-rmse:6.08290
# [92]	validation-rmse:6.08253
# [93]	validation-rmse:6.08124
# [94]	validation-rmse:6.08029
# [95]	validation-rmse:6.07945
# [96]	validation-rmse:6.07881
# [97]	validation-rmse:6.07671
# [98]	validation-rmse:6.07610
# [99]	validation-rmse:6.07498
# 100%|██████████████████████████████████████████████████████████████████████████████| 5/5 [11:09<00:00, 133.95s/trial, best loss: 5.9592349738760255]

# %%
mlflow.xgboost.autolog(disable= True)

# %%
with mlflow.start_run():
    best_params = {
    'learning_rate': 0.28,
    'max_depth':67,
    'min_child_weight':7.5,
    'objective':'reg:linear',
    'reg_alpha':0.3,
    'reg_lambda': 0.005,
    'seed':42,    
    }
    
    mlflow.log_params(best_params)
    
    booster = xgb.train(
            params = best_params,
            dtrain = train,
            num_boost_round = 70,
            evals = [(val, "validation")],
            early_stopping_rounds = 10,
    )
    
    y_pred = booster.predict(val)
    rmse = mean_squared_error(y_val, y_pred, squared = False)
    mlflow.log_metric('rmse', rmse)

    with open('models/preprocessor.b', "wb") as f_out:
        pickle.dump(dv,f_out)
        
    mlflow.log_artifact("models/preprocessor.b",artifact_path ='preprocessor')
    mlflow.xgboost.log_model(booster, artifact_path='models_mlflow')
# Out:
# /home/batya/.local/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [21:06:48] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:8.14629
# [1]	validation-rmse:7.47151
# [2]	validation-rmse:7.00664
# [3]	validation-rmse:6.77922
# [4]	validation-rmse:6.60240
# [5]	validation-rmse:6.51184
# [6]	validation-rmse:6.44964
# [7]	validation-rmse:6.38660
# [8]	validation-rmse:6.35728
# [9]	validation-rmse:6.32127
# [10]	validation-rmse:6.29715
# [11]	validation-rmse:6.26021
# [12]	validation-rmse:6.24874
# [13]	validation-rmse:6.23884
# [14]	validation-rmse:6.23163
# [15]	validation-rmse:6.21801
# [16]	validation-rmse:6.20572
# [17]	validation-rmse:6.19701
# [18]	validation-rmse:6.19082
# [19]	validation-rmse:6.18344
# [20]	validation-rmse:6.17780
# [21]	validation-rmse:6.16191
# [22]	validation-rmse:6.15929
# [23]	validation-rmse:6.15287
# [24]	validation-rmse:6.14836
# [25]	validation-rmse:6.14387
# [26]	validation-rmse:6.14003
# [27]	validation-rmse:6.13601
# [28]	validation-rmse:6.13033
# [29]	validation-rmse:6.11391
# [30]	validation-rmse:6.10794
# [31]	validation-rmse:6.10709
# [32]	validation-rmse:6.10328
# [33]	validation-rmse:6.10001
# [34]	validation-rmse:6.09796
# [35]	validation-rmse:6.09314
# [36]	validation-rmse:6.09344
# [37]	validation-rmse:6.08748
# [38]	validation-rmse:6.08671
# [39]	validation-rmse:6.08541
# [40]	validation-rmse:6.08285
# [41]	validation-rmse:6.08215
# [42]	validation-rmse:6.07926
# [43]	validation-rmse:6.07868
# [44]	validation-rmse:6.07592
# [45]	validation-rmse:6.07145
# [46]	validation-rmse:6.06910
# [47]	validation-rmse:6.06628
# [48]	validation-rmse:6.06313
# [49]	validation-rmse:6.05919
# [50]	validation-rmse:6.05731
# [51]	validation-rmse:6.05726
# [52]	validation-rmse:6.05425
# [53]	validation-rmse:6.05086
# [54]	validation-rmse:6.04987
# [55]	validation-rmse:6.04599
# [56]	validation-rmse:6.04520
# [57]	validation-rmse:6.04395
# [58]	validation-rmse:6.04153
# [59]	validation-rmse:6.04037
# [60]	validation-rmse:6.03875
# [61]	validation-rmse:6.03760
# [62]	validation-rmse:6.03582
# [63]	validation-rmse:6.03590
# [64]	validation-rmse:6.03424
# [65]	validation-rmse:6.03328
# [66]	validation-rmse:6.03203
# [67]	validation-rmse:6.03255
# [68]	validation-rmse:6.03008
# [69]	validation-rmse:6.02738
# /home/batya/.local/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [21:11:01] WARNING: /workspace/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
#   warnings.warn(smsg, UserWarning)

# %%
logged_model = 'runs:/82de4876966f4a4f9c9e8c3431b4699b/model'
loaded_model = mlflow.pyfunc.load_model(logged_model)
loaded_model
# Out:
# /home/batya/.local/lib/python3.8/site-packages/xgboost/core.py:160: UserWarning: [21:11:06] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# mlflow.pyfunc.loaded_model:
#   artifact_path: model
#   flavor: mlflow.xgboost
#   run_id: 82de4876966f4a4f9c9e8c3431b4699b

# %%
xgb_model = mlflow.xgboost.load_model(logged_model)

# %%
xgb_model

# %%
y_pred = xgb_model.predict(val)

# %%
rmse = mean_squared_error(y_val, y_pred, squared = False)

# %%
print(rmse)
# Out:
# 5.979650556649659
